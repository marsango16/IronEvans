# %% [markdown]
# **Favourite Holiday Destination in Summer 2023**

# %% [markdown]
# # TOC
# * [Food](#first-bullet)
# * [Hotel](#second-bullet)
# * [Site](#thirth-bullet)
# * [Photo](#fourth-bullet)
# * [Video](#fifth-bullet)

# %% [markdown]
# ## Food <a class="anchor" id="first-bullet"></a>

# %%
#This is my first user function
user_input=input("Enter your favourite food:")

# %% [markdown]
# ## Hotel <a class="anchor" id="second-bullet"></a>

# %%
#Hotel choice
hotel_input=input("Enter your favourite Hotel:")
# Out:
# Enter your favourite Hotel:Any 5 affordable 5 star Hotel

# %% [markdown]
# ## Site <a class="anchor" id="third-bullet"></a>

# %%
#touristic sites to visit
tour_sites= input ("city tour: ")
# Out:
# city tour: Paris

# %%
other_sites= list ["Parliamnent","Castle"]

# %% [markdown]
# ## Photo <a class="anchor" id="fourth-bullet"></a>

# %% [markdown]
# # **Photo1: My Son - Emmanuel**

# %% [markdown]
# ![Scanned_jpeg%205.jpg](attachment:Scanned_jpeg%205.jpg)

# %% [markdown]
# # **Photo2: Paris**
# ![Paris.jpeg](attachment:Paris.jpeg)

# %% [markdown]
# ## Video <a class="anchor" id="fifth-bullet"></a>

# %% [markdown]
# 3 things that the person likes to do at this destination
# ∙City tour
# ∙Visit Parliament
# ∙Visit museums

# %% [markdown]
# # **Video Link to Paris, France:**
# https://www.youtube.com/watch?v=gigbRUn6SfE
