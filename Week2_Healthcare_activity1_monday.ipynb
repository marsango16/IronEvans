# %% [markdown]
# ## Health Care: Activity1_Case Study

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import minmax_scale
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy.stats import boxcox
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
pd.options.display.max_rows = 50
## Install xlrd package to load Excel files
# conda install openpyxl
## conda install xlrd

# %%
file1 = pd.read_csv('file1.csv')
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
file1 = pd.read_csv('file1.csv')
print(file1.head())
print(file1.tail())
file1.columns=[i.lower() for i in file1.columns]
#print(file1.tail())
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247
# 3            SUV          529.881344
# 4  Four-Door Car           17.269323
#      Customer   ST GENDER Education Customer Lifetime Value  Income  \
# 4003      NaN  NaN    NaN       NaN                     NaN     NaN
# 4004      NaN  NaN    NaN       NaN                     NaN     NaN
# 4005      NaN  NaN    NaN       NaN                     NaN     NaN
# 4006      NaN  NaN    NaN       NaN                     NaN     NaN
# 4007      NaN  NaN    NaN       NaN                     NaN     NaN
#
#       Monthly Premium Auto Number of Open Complaints Policy Type  \
# 4003                   NaN                       NaN         NaN
# 4004                   NaN                       NaN         NaN
# 4005                   NaN                       NaN         NaN
# 4006                   NaN                       NaN         NaN
# 4007                   NaN                       NaN         NaN
#
#      Vehicle Class  Total Claim Amount
# 4003           NaN                 NaN
# 4004           NaN                 NaN
# 4005           NaN                 NaN
# 4006           NaN                 NaN
# 4007           NaN                 NaN

# %%
file2 = pd.read_csv('file2.csv')
file2 =pd.DataFrame(file2)
print(file2.head())
file2.columns=[i.lower() for i in file2.columns]
print(file2.tail())
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# 2   Personal Auto   Two-Door Car
# 3   Personal Auto     Luxury Car
# 4  Corporate Auto   Two-Door Car
#     customer          st gender education customer lifetime value  income  \
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# 991                    70                    1/0/00          185.667213
# 992                    68                    1/0/00          140.747286
# 993                    70                    1/0/00          471.050488
# 994                    96                    1/0/00           28.460568
# 995                   111                    1/0/00          700.349052
#
#         policy type  vehicle class
# 991   Personal Auto  Four-Door Car
# 992  Corporate Auto  Four-Door Car
# 993  Corporate Auto   Two-Door Car
# 994   Personal Auto   Two-Door Car
# 995   Personal Auto            SUV

# %%
file3 = pd.read_csv('file3.csv')
file3 =pd.DataFrame(file3)
print(file3.head())
file3.columns=[i.lower() for i in file3.columns]
print(file3.tail())
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# 0          499.200000   Two-Door Car
# 1            3.468912   Two-Door Car
# 2          393.600000  Four-Door Car
# 3          699.615192            SUV
# 4          484.800000            SUV
#      customer       state  customer lifetime value education gender  income  \
# 7065  LA72316  California             23405.987980  Bachelor      M   71941
# 7066  PK87824  California              3096.511217   College      F   21604
# 7067  TD14365  California              8163.890428  Bachelor      M       0
# 7068  UP19263  California              7524.442436   College      M   21941
# 7069  Y167826  California              2611.836866   College      M       0
#
#       monthly premium auto  number of open complaints     policy type  \
# 7065                    73                          0   Personal Auto
# 7066                    79                          0  Corporate Auto
# 7067                    85                          3  Corporate Auto
# 7068                    96                          0   Personal Auto
# 7069                    77                          0  Corporate Auto
#
#       total claim amount  vehicle class
# 7065          198.234764  Four-Door Car
# 7066          379.200000  Four-Door Car
# 7067          790.784983  Four-Door Car
# 7068          691.200000  Four-Door Car
# 7069          369.600000   Two-Door Car

# %%
#concatinate the 3 files into 1 file
file4 = pd.concat([file1, file2,file3], axis=0)
print(len(file1))
print(len(file2))
print(len(file3))
print(len(file4))
print(file4.head())
file4
# Out:
# 4008
# 996
# 7070
# 12074
#   customer          st gender             education customer lifetime value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly premium auto number of open complaints     policy type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle class  total claim amount state
# 0  Four-Door Car            2.704934   NaN
# 1  Four-Door Car         1131.464935   NaN
# 2   Two-Door Car          566.472247   NaN
# 3            SUV          529.881344   NaN
# 4  Four-Door Car           17.269323   NaN
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 7065             23405.98798  71941.0                  73.0
# 7066             3096.511217  21604.0                  79.0
# 7067             8163.890428      0.0                  85.0
# 7068             7524.442436  21941.0                  96.0
# 7069             2611.836866      0.0                  77.0
#
#      number of open complaints     policy type  vehicle class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 7065                         0   Personal Auto  Four-Door Car
# 7066                         0  Corporate Auto  Four-Door Car
# 7067                         3  Corporate Auto  Four-Door Car
# 7068                         0   Personal Auto  Four-Door Car
# 7069                         0  Corporate Auto   Two-Door Car
#
#       total claim amount       state
# 0               2.704934         NaN
# 1            1131.464935         NaN
# 2             566.472247         NaN
# 3             529.881344         NaN
# 4              17.269323         NaN
# ...                  ...         ...
# 7065          198.234764  California
# 7066          379.200000  California
# 7067          790.784983  California
# 7068          691.200000  California
# 7069          369.600000  California
#
# [12074 rows x 12 columns]

# %%
#standardizing headers
#replace spaces with "_"
file4.columns = file4.columns.str.replace(" ", "_")
file4
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 7065             23405.98798  71941.0                  73.0
# 7066             3096.511217  21604.0                  79.0
# 7067             8163.890428      0.0                  85.0
# 7068             7524.442436  21941.0                  96.0
# 7069             2611.836866      0.0                  77.0
#
#      number_of_open_complaints     policy_type  vehicle_class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 7065                         0   Personal Auto  Four-Door Car
# 7066                         0  Corporate Auto  Four-Door Car
# 7067                         3  Corporate Auto  Four-Door Car
# 7068                         0   Personal Auto  Four-Door Car
# 7069                         0  Corporate Auto   Two-Door Car
#
#       total_claim_amount       state
# 0               2.704934         NaN
# 1            1131.464935         NaN
# 2             566.472247         NaN
# 3             529.881344         NaN
# 4              17.269323         NaN
# ...                  ...         ...
# 7065          198.234764  California
# 7066          379.200000  California
# 7067          790.784983  California
# 7068          691.200000  California
# 7069          369.600000  California
#
# [12074 rows x 12 columns]

# %%
#Removing duplicates
df=file4
df.drop_duplicates()
print(len(file4))
print(len(df))
df
# Out:
# 12074
# 12074
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# 3                  764586.18      0.0                 106.0
# 4                  536307.65  36357.0                  68.0
# ...                      ...      ...                   ...
# 7065                     NaN  71941.0                  73.0
# 7066                     NaN  21604.0                  79.0
# 7067                     NaN      0.0                  85.0
# 7068                     NaN  21941.0                  96.0
# 7069                     NaN      0.0                  77.0
#
#      number_of_open_complaints     policy_type  vehicle_class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 7065                         0   Personal Auto  Four-Door Car
# 7066                         0  Corporate Auto  Four-Door Car
# 7067                         3  Corporate Auto  Four-Door Car
# 7068                         0   Personal Auto  Four-Door Car
# 7069                         0  Corporate Auto   Two-Door Car
#
#       total_claim_amount       state
# 0               2.704934         NaN
# 1            1131.464935         NaN
# 2             566.472247         NaN
# 3             529.881344         NaN
# 4              17.269323         NaN
# ...                  ...         ...
# 7065          198.234764  California
# 7066          379.200000  California
# 7067          790.784983  California
# 7068          691.200000  California
# 7069          369.600000  California
#
# [12074 rows x 12 columns]

# %%
#Deleting and rearranging columns – delete the column customer as it is only a unique identifier for each row of data
df.drop(columns=['customer'], inplace=True)
df
# Out:
#               st gender             education customer_lifetime_value  \
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor               697953.59
# 2         Nevada      F              Bachelor              1288743.17
# 3     California      M              Bachelor               764586.18
# 4     Washington      M  High School or Below               536307.65
# ...          ...    ...                   ...                     ...
# 7065         NaN      M              Bachelor                     NaN
# 7066         NaN      F               College                     NaN
# 7067         NaN      M              Bachelor                     NaN
# 7068         NaN      M               College                     NaN
# 7069         NaN      M               College                     NaN
#
#        income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0         0.0                1000.0                    1/0/00   Personal Auto
# 1         0.0                  94.0                    1/0/00   Personal Auto
# 2     48767.0                 108.0                    1/0/00   Personal Auto
# 3         0.0                 106.0                    1/0/00  Corporate Auto
# 4     36357.0                  68.0                    1/0/00   Personal Auto
# ...       ...                   ...                       ...             ...
# 7065  71941.0                  73.0                         0   Personal Auto
# 7066  21604.0                  79.0                         0  Corporate Auto
# 7067      0.0                  85.0                         3  Corporate Auto
# 7068  21941.0                  96.0                         0   Personal Auto
# 7069      0.0                  77.0                         0  Corporate Auto
#
#       vehicle_class  total_claim_amount       state
# 0     Four-Door Car            2.704934         NaN
# 1     Four-Door Car         1131.464935         NaN
# 2      Two-Door Car          566.472247         NaN
# 3               SUV          529.881344         NaN
# 4     Four-Door Car           17.269323         NaN
# ...             ...                 ...         ...
# 7065  Four-Door Car          198.234764  California
# 7066  Four-Door Car          379.200000  California
# 7067  Four-Door Car          790.784983  California
# 7068  Four-Door Car          691.200000  California
# 7069   Two-Door Car          369.600000  California
#
# [12074 rows x 11 columns]

# %%
#Working with data types – Check the data types of all the columns and fix the incorrect ones (for ex. customer lifetime value and number of open complaints ). Hint: remove the percentage from the customer lifetime value and truncate it to an integer value.
#Check the data types of all the columns
print(df)
df.dtypes
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 7065             23405.98798  71941.0                  73.0
# 7066             3096.511217  21604.0                  79.0
# 7067             8163.890428      0.0                  85.0
# 7068             7524.442436  21941.0                  96.0
# 7069             2611.836866      0.0                  77.0
#
#      number_of_open_complaints     policy_type  vehicle_class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 7065                         0   Personal Auto  Four-Door Car
# 7066                         0  Corporate Auto  Four-Door Car
# 7067                         3  Corporate Auto  Four-Door Car
# 7068                         0   Personal Auto  Four-Door Car
# 7069                         0  Corporate Auto   Two-Door Car
#
#       total_claim_amount       state
# 0               2.704934         NaN
# 1            1131.464935         NaN
# 2             566.472247         NaN
# 3             529.881344         NaN
# 4              17.269323         NaN
# ...                  ...         ...
# 7065          198.234764  California
# 7066          379.200000  California
# 7067          790.784983  California
# 7068          691.200000  California
# 7069          369.600000  California
#
# [12074 rows x 12 columns]
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# state                         object
# dtype: object

# %%
#customer_lifetime_value should be a float or numeric, not an object
dfa=df
dfa['customer_lifetime_value'] =  pd.to_numeric(df['customer_lifetime_value'], errors='coerce')
print(dfa.dtypes)
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# state                         object
# dtype: object

# %%
#number of open complaints should be numeric or float
dfb=dfa
dfb['number_of_open_complaints'] =  pd.to_numeric(df['number_of_open_complaints'], errors='coerce')
print(dfb.dtypes)
# Out:
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints    float64
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# state                         object
# dtype: object

# %%
#remove the percentage from the customer lifetime value and truncate it to an integer value.
dfc=file4
dfc
#dfc['customer_lifetime_value'].replace({"%",""},regex=True)
dfc['customer_lifetime_value'] = dfc['customer_lifetime_value'].str.replace('%', '')
#dfc['customer_lifetime_value'] = dfc['customer_lifetime_value'].str.findall(r'(\d)').str.join('')
dfc
#round(dfc.isna().sum()/len(hk_df),4)*100
#round(dfc['customer_lifetime_value'],1)

#dfc['customer_lifetime_value'] = np.round(dfc['customer_lifetime_value'], decimals = 1)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# 3                  764586.18      0.0                 106.0
# 4                  536307.65  36357.0                  68.0
# ...                      ...      ...                   ...
# 7065                     NaN  71941.0                  73.0
# 7066                     NaN  21604.0                  79.0
# 7067                     NaN      0.0                  85.0
# 7068                     NaN  21941.0                  96.0
# 7069                     NaN      0.0                  77.0
#
#      number_of_open_complaints     policy_type  vehicle_class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 7065                         0   Personal Auto  Four-Door Car
# 7066                         0  Corporate Auto  Four-Door Car
# 7067                         3  Corporate Auto  Four-Door Car
# 7068                         0   Personal Auto  Four-Door Car
# 7069                         0  Corporate Auto   Two-Door Car
#
#       total_claim_amount       state
# 0               2.704934         NaN
# 1            1131.464935         NaN
# 2             566.472247         NaN
# 3             529.881344         NaN
# 4              17.269323         NaN
# ...                  ...         ...
# 7065          198.234764  California
# 7066          379.200000  California
# 7067          790.784983  California
# 7068          691.200000  California
# 7069          369.600000  California
#
# [12074 rows x 12 columns]

# %%
#clean the number of open complaints and extract the middle number which is changing between records.
dfd= dfc
dfd['number_of_open_complaints'].str.extract(r'(\/([A-Z]+\))')
dfd
#df[['number_of_open_complaints']] = df['number_of_open_complaints'].str.split('/', expand=True)

working on it still....
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [175], in <cell line: 3>()
#       1 #clean the number of open complaints and extract the middle number which is changing between records.
#       2 dfd= dfc
# ----> 3 dfd['number_of_open_complaints'].str.extract(r'(\/([A-Z]+\))')
#       4 dfd
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/strings/accessor.py:125, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     120     msg = (
#     121         f"Cannot use .str.{func_name} with values of "
#     122         f"inferred dtype '{self._inferred_dtype}'."
#     123     )
#     124     raise TypeError(msg)
# --> 125 return func(self, *args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/strings/accessor.py:2527, in StringMethods.extract(self, pat, flags, expand)
#    2524 if not isinstance(expand, bool):
#    2525     raise ValueError("expand must be True or False")
# -> 2527 regex = re.compile(pat, flags=flags)
#    2528 if regex.groups == 0:
#    2529     raise ValueError("pattern contains no capture groups")
#
# File ~/opt/anaconda3/lib/python3.9/re.py:252, in compile(pattern, flags)
#     250 def compile(pattern, flags=0):
#     251     "Compile a regular expression pattern, returning a Pattern object."
# --> 252     return _compile(pattern, flags)
#
# File ~/opt/anaconda3/lib/python3.9/re.py:304, in _compile(pattern, flags)
#     302 if not sre_compile.isstring(pattern):
#     303     raise TypeError("first argument must be string or compiled pattern")
# --> 304 p = sre_compile.compile(pattern, flags)
#     305 if not (flags & DEBUG):
#     306     if len(_cache) >= _MAXCACHE:
#     307         # Drop the oldest item
#
# File ~/opt/anaconda3/lib/python3.9/sre_compile.py:764, in compile(p, flags)
#     762 if isstring(p):
#     763     pattern = p
# --> 764     p = sre_parse.parse(p, flags)
#     765 else:
#     766     pattern = None
#
# File ~/opt/anaconda3/lib/python3.9/sre_parse.py:950, in parse(str, flags, state)
#     947 state.str = str
#     949 try:
# --> 950     p = _parse_sub(source, state, flags & SRE_FLAG_VERBOSE, 0)
#     951 except Verbose:
#     952     # the VERBOSE flag was switched on inside the pattern.  to be
#     953     # on the safe side, we'll parse the whole thing again...
#     954     state = State()
#
# File ~/opt/anaconda3/lib/python3.9/sre_parse.py:443, in _parse_sub(source, state, verbose, nested)
#     441 start = source.tell()
#     442 while True:
# --> 443     itemsappend(_parse(source, state, verbose, nested + 1,
#     444                        not nested and not items))
#     445     if not sourcematch("|"):
#     446         break
#
# File ~/opt/anaconda3/lib/python3.9/sre_parse.py:838, in _parse(source, state, verbose, nested, first)
#     836 p = _parse_sub(source, state, sub_verbose, nested + 1)
#     837 if not source.match(")"):
# --> 838     raise source.error("missing ), unterminated subpattern",
#     839                        source.tell() - start)
#     840 if group is not None:
#     841     state.closegroup(group, p)
#
# error: missing ), unterminated subpattern at position 0

# %%
# Filtering data and Correcting typos – Filter the data in state and gender column to standardize the texts in those columns
Working on it
